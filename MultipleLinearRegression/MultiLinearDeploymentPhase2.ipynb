# %%
# loading pickle to save final model
import pickle

# %%
loaded_model = pickle.load(open('finalized_model_multilinear.sav','rb'))

# %%
# we need to give input for testing base on how much input we have in training set
# so we give 5 inputs inside for testing

result = loaded_model.predict([[1434,145,4565,0,1]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[43988.69672827]])
